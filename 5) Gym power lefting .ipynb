# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data:

df = pd.read_csv(r"G:\powerlifting_dataset.csv")

# %%
# top 3 rows of dataset:

df.head(3)
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235

# %%
# last 3 rows of dataset:

df.tail(3)
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
# All the rows except the last 3 rows:

df.head(-3)
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2992        John Doe   51        52 kg  Bench Press                 170
# 2993    Laura Taylor   42        66 kg        Squat                 187
# 2994    Sarah Thomas   62       105 kg  Bench Press                 191
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
#
# [2997 rows x 5 columns]

# %%
# all the rows expect the first 3 rows:

df.tail(-3)
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# 5       Sarah Thomas   56        74 kg        Squat                 264
# 6        Emily Davis   40        83 kg     Deadlift                 132
# 7     Jessica Wilson   25       120 kg  Bench Press                 178
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [2997 rows x 5 columns]

# %%
# find the shape of dataset:

df.shape #shape is attribute not a method.
# Out:
# (3000, 5)

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 3000
# Number of columns: 5

# %%
df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
df['Age'].shape
# Out:
# (3000,)

# %%
# information about dataset:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
# check null values:

df.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
# get statistics of dataset:

df.describe() #shows only numerical stats
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
# find unique values form dataset:

df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
df['Weight Class'].unique()
# Out:
# array(['59 kg', '83 kg', '105 kg', '66 kg', '74 kg', '120 kg', '93 kg',
#        '52 kg', 'Open'], dtype=object)

# %%
df['Weight Class'].nunique()
# Out:
# 9

# %%
df.nunique()
# Out:
# Lifter Name            10
# Age                    47
# Weight Class            9
# Lift Type               3
# Amount Lifted (kg)    300
# dtype: int64

# %%
# display count of the unique values in age column:

df['Weight Class'].value_counts()
# Out:
# Weight Class
# 93 kg     359
# Open      356
# 59 kg     348
# 83 kg     327
# 66 kg     326
# 52 kg     326
# 74 kg     321
# 120 kg    319
# 105 kg    318
# Name: count, dtype: int64

# %%
df['Weight Class']
# Out:
# 0        59 kg
# 1        83 kg
# 2       105 kg
# 3        66 kg
# 4        74 kg
#          ...
# 2995     74 kg
# 2996      Open
# 2997      Open
# 2998     93 kg
# 2999     83 kg
# Name: Weight Class, Length: 3000, dtype: object

# %%
df.sort_values(by='Weight Class',)
# Out:
#            Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1481      Laura Taylor   35       105 kg  Bench Press                 343
# 702         Jane Smith   48       105 kg  Bench Press                 127
# 283        Emily Davis   21       105 kg  Bench Press                 304
# 282        Chris Brown   19       105 kg        Squat                 310
# 1190          John Doe   36       105 kg     Deadlift                 181
# ...                ...  ...          ...          ...                 ...
# 1242   Michael Johnson   51         Open     Deadlift                 147
# 1977       Emily Davis   30         Open  Bench Press                 263
# 303    Michael Johnson   42         Open        Squat                 208
# 649   Matthew Anderson   64         Open        Squat                 350
# 2142      Sarah Thomas   56         Open     Deadlift                 337
#
# [3000 rows x 5 columns]

# %%
# names of age 50 above

df[df['Age']>50] ['Lifter Name']
# Out:
# 1               John Doe
# 4           Laura Taylor
# 5           Sarah Thomas
# 8        Michael Johnson
# 12      Matthew Anderson
#               ...
# 2989         Chris Brown
# 2991            John Doe
# 2992            John Doe
# 2994        Sarah Thomas
# 2997        Sarah Thomas
# Name: Lifter Name, Length: 917, dtype: object

# %%
df[df['Age'].between(40,50)]['Lifter Name']
# Out:
# 0         Jessica Wilson
# 2            Emily Davis
# 6            Emily Davis
# 13      Matthew Anderson
# 14            Jane Smith
#               ...
# 2977      Jessica Wilson
# 2979          Jane Smith
# 2980            John Doe
# 2993        Laura Taylor
# 2995            John Doe
# Name: Lifter Name, Length: 708, dtype: object

# %%
# name of loweset weightlifing:

df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
df[df['Weight Class'].min() == df['Weight Class']] [['Lifter Name','Weight Class']]
# Out:
#          Lifter Name Weight Class
# 2        Emily Davis       105 kg
# 17      Laura Taylor       105 kg
# 25       Emily Davis       105 kg
# 28    Jessica Wilson       105 kg
# 29          John Doe       105 kg
# ...              ...          ...
# 2969      Jane Smith       105 kg
# 2981    Laura Taylor       105 kg
# 2984      Daniel Lee       105 kg
# 2987        John Doe       105 kg
# 2994    Sarah Thomas       105 kg
#
# [318 rows x 2 columns]

# %%
# top 5 weightlifts:

df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
df.sort_values(by='Weight Class')[['Lifter Name','Weight Class']]
# Out:
#            Lifter Name Weight Class
# 1481      Laura Taylor       105 kg
# 702         Jane Smith       105 kg
# 283        Emily Davis       105 kg
# 282        Chris Brown       105 kg
# 1190          John Doe       105 kg
# ...                ...          ...
# 1242   Michael Johnson         Open
# 1977       Emily Davis         Open
# 303    Michael Johnson         Open
# 649   Matthew Anderson         Open
# 2142      Sarah Thomas         Open
#
# [3000 rows x 2 columns]

# %%
#avg. weightlifing:

df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
df['Weight Class'].min()
# Out:
# '105 kg'

# %%
df['Weight Class'].max()
# Out:
# 'Open'

# %%
df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.countplot(data=df,y='Lift Type')
# Out:
# <Axes: xlabel='count', ylabel='Lift Type'>

# %%
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df=df[df['Age']>50]

sns.boxplot(data=df, x="Age", y='Amount Lifted (kg)')
# Out:
# <Axes: xlabel='Age', ylabel='Amount Lifted (kg)'>

# %%
sns.boxplot(data=df, x="Age", y='Amount Lifted (kg)')
# Out:
# <Axes: xlabel='Age', ylabel='Amount Lifted (kg)'>

# %%
df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
sns.lineplot(data=df, x="Amount Lifted (kg)", y="Age")
# Out:
# <Axes: xlabel='Amount Lifted (kg)', ylabel='Age'>

# %%
df.head()
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1           John Doe   60        83 kg  Bench Press                 179
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# 5       Sarah Thomas   56        74 kg        Squat                 264
# 8    Michael Johnson   55        93 kg        Squat                 265
# 12  Matthew Anderson   64        74 kg  Bench Press                 398

# %% [markdown]
# type of lifttype

# %%
sns.countplot(x=df['Lift Type'])
plt.xlabel("types of lifting")
# Out:
# Text(0.5, 0, 'types of lifting')

# %%
df.head()
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1           John Doe   60        83 kg  Bench Press                 179
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# 5       Sarah Thomas   56        74 kg        Squat                 264
# 8    Michael Johnson   55        93 kg        Squat                 265
# 12  Matthew Anderson   64        74 kg  Bench Press                 398

# %%
data=df.groupby('Lift Type')['Age'].sum()
result=pd.DataFrame({'Age':data})
plt.plot(result,c='green',marker='o')
plt.xlabel("type of weights",c="red",size=20)
plt.ylabel("Lift Type",c="red",size=20)
# Out:
# Text(0, 0.5, 'Lift Type')

# %%
# Getting histogram based  values
print(df.head().hist())
print(df.tail().hist())
# Out:
# [[<Axes: title={'center': 'Age'}>
#   <Axes: title={'center': 'Amount Lifted (kg)'}>]]
# [[<Axes: title={'center': 'Age'}>
#   <Axes: title={'center': 'Amount Lifted (kg)'}>]]

# %%
#. Getting blox plots for lifter names based on the lift types
print(sns.boxplot(x = 'Lift Type', y = 'Lifter Name', data = df ))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
#Pair plots
print(sns.pairplot(df))

# %%
#Pie charts
df['Lift Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
#1: Top 5 names based on top top lifted weights
highest_weight = df['Amount Lifted (kg)'].max()
# Print the highest weight
print(f"The highest weight lifted is: {highest_weight} kg")
top_5 = df.sort_values(by='Amount Lifted (kg)', ascending=False).head(5)
# Select only the 'Name' and 'Amount Lifted (kg)' columns
result = top_5[['Lifter Name', 'Amount Lifted (kg)']]
print(result)
# Out:
# The highest weight lifted is: 399 kg
#           Lifter Name  Amount Lifted (kg)
# 2140       Jane Smith                 399
# 2105  Michael Johnson                 399
# 1207  Michael Johnson                 399
# 2699      Emily Davis                 399
# 1727     Sarah Thomas                 399

# %%
#2: Count of lift types with names 
counts=print(df['Lift Type'].value_counts())
# Out:
# Lift Type
# Bench Press    328
# Deadlift       300
# Squat          289
# Name: count, dtype: int64

# %%
#3: Printing the Lifter names of age greater than 50 and box plotting the related data
age50lifters = df[df['Age'] > 50]
print("Lifter names with age greater than 50:")
print(age50lifters['Lifter Name'])
print(sns.boxplot(age50lifters))
plt.title('Box Plot of age for Lifters Older Than 50')
plt.show()
# Out:
# Lifter names with age greater than 50:
# 1               John Doe
# 4           Laura Taylor
# 5           Sarah Thomas
# 8        Michael Johnson
# 12      Matthew Anderson
#               ...
# 2989         Chris Brown
# 2991            John Doe
# 2992            John Doe
# 2994        Sarah Thomas
# 2997        Sarah Thomas
# Name: Lifter Name, Length: 917, dtype: object
# Axes(0.125,0.11;0.775x0.77)

# %%
#4 : Get the names of lifters whose age is greater than 100
# Ensure 'Weight Class' is numeric (if it's not already)
df['Weight Class'] = pd.to_numeric(df['Weight Class'], errors='coerce')
# Filter lifters with weight greater than 100
w_lifters = df[df['Weight Class'] > 100]
# Check if there are any lifters with weight greater than 100 and print their names
if not w_lifters.empty:
    print("Lifter names with weight greater than 100:")
    print(w_lifters['Lifter Name'])
else:
    print("No lifters found with weight greater than 100.")
# Out:
# No lifters found with weight greater than 100.

# %%
#5 : Get the names of the people who did only deadlifts
deadlift_lifters = df[df['Lift Type'] == 'Deadlift']
# Get the names of these lifters
deadlift_names = deadlift_lifters['Lifter Name'].unique()
# Print the names
print("Lifter names who performed only deadlifts:")
print(deadlift_names)
# Out:
# Lifter names who performed only deadlifts:
# ['Laura Taylor' 'John Doe' 'Jane Smith' 'Michael Johnson'
#  'Matthew Anderson' 'Emily Davis' 'Chris Brown' 'Daniel Lee'
#  'Sarah Thomas' 'Jessica Wilson']
