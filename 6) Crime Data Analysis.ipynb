# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"G:\crime_data.csv")

# %%
df
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 0       SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1       CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2       CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3       CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4                  CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
# ...                                                   ...       ...      ...
# 230540                                    BRANDISH WEAPON        38        M
# 230541                                            ROBBERY        23        F
# 230542                                            ROBBERY        65        F
# 230543                  INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent                                   Premis Desc  \
# 0                 H                        SINGLE FAMILY DWELLING
# 1                 W  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 2                 H  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3                 H  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 4                 W                        SINGLE FAMILY DWELLING
# ...             ...                                           ...
# 230540            H                                        STREET
# 230541            B                                        STREET
# 230542            W                                      SIDEWALK
# 230543            W                        SINGLE FAMILY DWELLING
# 230544            H                                      SIDEWALK
#
#                                            Weapon Desc  Status Desc  \
# 0       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 1       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 2       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 3       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 4                          UNKNOWN WEAPON/OTHER WEAPON  Adult Other
# ...                                                ...          ...
# 230540                KNIFE WITH BLADE 6INCHES OR LESS  Adult Other
# 230541  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 230542  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 230543  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 230544  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
#
#                                         LOCATION
# 0       13400    RANGOON                      ST
# 1         900 N  MARIPOSA                     AV
# 2        8500    COLUMBUS                     AV
# 3        1700 S  WESTMORELAND                 AV
# 4        2800    WAVERLY                      DR
# ...                                          ...
# 230540  11000    MCCORMICK                    ST
# 230541   5500    HOLLYWOOD                    BL
# 230542  11000    FOOTHILL                     BL
# 230543    800    BARTLETT                     ST
# 230544  12800    FILMORE                      ST
#
# [230545 rows x 15 columns]

# %%
df.head()
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0  2022-04-12  2020-10-01    00:01    19    Mission         1     821
# 1  2023-01-05  2020-02-01    08:00     2    Rampart         2     812
# 2  2023-03-21  2020-03-15    12:00    19    Mission         2     812
# 3  2023-06-04  2020-07-01    12:00    20    Olympic         2     812
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4             CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
#
#   Vict Descent                                   Premis Desc  \
# 0            H                        SINGLE FAMILY DWELLING
# 1            W  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 2            H  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3            H  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 4            W                        SINGLE FAMILY DWELLING
#
#                                       Weapon Desc  Status Desc  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 1  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 2  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 3  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 4                     UNKNOWN WEAPON/OTHER WEAPON  Adult Other
#
#                                    LOCATION
# 0  13400    RANGOON                      ST
# 1    900 N  MARIPOSA                     AV
# 2   8500    COLUMBUS                     AV
# 3   1700 S  WESTMORELAND                 AV
# 4   2800    WAVERLY                      DR

# %%
df.tail()
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 230540                                 BRANDISH WEAPON        38        M
# 230541                                         ROBBERY        23        F
# 230542                                         ROBBERY        65        F
# 230543               INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent             Premis Desc  \
# 230540            H                  STREET
# 230541            B                  STREET
# 230542            W                SIDEWALK
# 230543            W  SINGLE FAMILY DWELLING
# 230544            H                SIDEWALK
#
#                                            Weapon Desc  Status Desc  \
# 230540                KNIFE WITH BLADE 6INCHES OR LESS  Adult Other
# 230541  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
# 230542  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 230543  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 230544  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
#
#                                         LOCATION
# 230540  11000    MCCORMICK                    ST
# 230541   5500    HOLLYWOOD                    BL
# 230542  11000    FOOTHILL                     BL
# 230543    800    BARTLETT                     ST
# 230544  12800    FILMORE                      ST

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
df.describe()
# Out:
#                 AREA       Part 1-2         Crm Cd       Vict Age
# count  230545.000000  230545.000000  230545.000000  230545.000000
# mean       10.466881       1.544991     508.044629      34.451513
# std         6.225582       0.497973     240.542475      18.003355
# min         1.000000       1.000000     110.000000      -2.000000
# 25%         5.000000       1.000000     230.000000      23.000000
# 50%        11.000000       2.000000     624.000000      33.000000
# 75%        16.000000       2.000000     626.000000      46.000000
# max        21.000000       2.000000     956.000000      99.000000

# %%
df.isnull().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
duplicates = df[df.duplicated()]
# Display duplicate rows
print(duplicates)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 5361    2021-05-16  2021-05-16    13:15    14      Pacific         2     622
# 5411    2021-09-08  2021-09-08    21:00    13       Newton         2     624
# 6480    2021-10-22  2021-10-22    19:15     5       Harbor         1     230
# 7692    2021-02-11  2021-02-11    17:20    12  77th Street         2     623
# 8575    2021-04-15  2021-04-15    00:30     3    Southwest         1     230
# ...            ...         ...      ...   ...          ...       ...     ...
# 230294  2023-01-12  2023-01-12    15:50    13       Newton         2     437
# 230473  2023-05-21  2023-05-19    22:30    16     Foothill         2     437
# 230474  2023-06-18  2023-06-18    15:30     5       Harbor         1     230
# 230489  2023-11-12  2023-11-12    01:20     3    Southwest         2     624
# 230512  2023-07-11  2023-07-10    19:30    13       Newton         2     624
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 5361                          BATTERY ON A FIREFIGHTER         0        M
# 5411                          BATTERY - SIMPLE ASSAULT        69        F
# 6480    ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        19        M
# 7692                           BATTERY POLICE (SIMPLE)         0        X
# 8575    ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        17        M
# ...                                                ...       ...      ...
# 230294                                RESISTING ARREST         0        M
# 230473                                RESISTING ARREST         0        M
# 230474  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        22        M
# 230489                        BATTERY - SIMPLE ASSAULT        24        F
# 230512                        BATTERY - SIMPLE ASSAULT        27        M
#
#        Vict Descent                        Premis Desc  \
# 5361              O  TRANSPORTATION FACILITY (AIRPORT)
# 5411              H                           SIDEWALK
# 6480              H                             STREET
# 7692              X                             STREET
# 8575              B             SINGLE FAMILY DWELLING
# ...             ...                                ...
# 230294            H                    POLICE FACILITY
# 230473            H                             STREET
# 230474            H                              ALLEY
# 230489            H                             STREET
# 230512            H                    PARK/PLAYGROUND
#
#                                            Weapon Desc   Status Desc  \
# 5361    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Arrest
# 5411    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# 6480                                   UNKNOWN FIREARM   Invest Cont
# 7692    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Arrest
# 8575                                          HAND GUN   Invest Cont
# ...                                                ...           ...
# 230294                     UNKNOWN WEAPON/OTHER WEAPON  Adult Arrest
# 230473  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Adult Other
# 230474                                        HAND GUN   Invest Cont
# 230489  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# 230512  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
#
#                                        LOCATION
# 5361     200    WORLD                        WY
# 5411                                   FLORENCE
# 6480            21ST                         ST
# 7692     800 W  52ND                         ST
# 8575    3800    LA SALLE                     AV
# ...                                         ...
# 230294  3400 S  CENTRAL                      AV
# 230473                                     FAIR
# 230474       N  21ST                         ST
# 230489  2800 S  REDONDO                      BL
# 230512   300 E  51ST                         ST
#
# [1211 rows x 15 columns]

# %%
#Since we got duplicates, we must remove them 
data=df.drop_duplicates(inplace=True)
print(data)
# Out:
# None

# %%
# Count of each crime type
top_n = 15
top_crimes = df['Crm Cd Desc'].value_counts().nlargest(top_n)
plt.figure(figsize=(15, 10))
sns.barplot(x=top_crimes.values, y=top_crimes.index)
plt.title(f'Top {top_n} Most Common Crime Types', fontsize=16)
plt.xlabel('Number of Incidents', fontsize=14)
plt.ylabel('Crime Type', fontsize=14)
plt.show()

# %%
# draw lineplot 
sns.lineplot(x="Vict Age", y="Weapon Desc", data=df)
# Out:
# <Axes: xlabel='Vict Age', ylabel='Weapon Desc'>

# %%
sns.barplot(x='Vict Sex',y='Vict Age',data=df)
# Out:
# <Axes: xlabel='Vict Sex', ylabel='Vict Age'>

# %%
plt.figure(figsize=(15, 12))
sns.histplot(df['Vict Age'].dropna(), bins=30, kde=True)
plt.title('Distribution of Victim Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x='Vict Sex', data=df)
plt.title('Gender Distribution of Victims')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='AREA NAME', data=df, order=df['AREA NAME'].value_counts().index)
plt.title('Crimes by Area')
plt.show()

# %%
# Select numeric columns for correlation analysis
numeric_data = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.hist(figsize=(12, 10), bins=30)
plt.suptitle('Histograms of Numerical Features in Crime Data')
plt.show()

# %%
# Get the top 10 most frequent crime types
top_crimes = df['Crm Cd Desc'].value_counts().nlargest(10).index

# Filter the data for these top crimes
filtered_data = df[df['Crm Cd Desc'].isin(top_crimes)]

# Create the box plot
plt.figure(figsize=(20,15))
sns.boxplot(x='Crm Cd Desc', y='Vict Age', data=filtered_data)
plt.title('Victim\'s Age by Top 10 Crime Types')
plt.xlabel('Crime Type')
plt.ylabel('Victim\'s Age')
plt.xticks(rotation=403)  # Rotate x labels for better readability
plt.show()

# %%
sns.pairplot(data=df)
